# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 24.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip uninstall torch torchvision torchaudio
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# from ultralytics import YOLO

# # Load a pre-trained YOLOv8 segmentation model
# model = YOLO("yolo11n.pt")  # 'n' is lightweight; use 'm' or 'l' for better accuracy

# results = model.train(data="coco.yaml", epochs=100, imgsz=640)

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 segmentation model
model = YOLO("yolo11n.pt")  # 'n' is lightweight; use 'm' or 'l' for better accuracy

# Train the model
results = model.train(
    data="/content/drive/MyDrive/Prof. Xiao Zhang TAI Lab/Tape Nail/YOLO2/data.yaml",  # Roboflow should have generated this
    epochs=100,         # Adjust based on dataset size
    imgsz=256,         # Resize images to 640x640
    batch=16,          # Adjust based on GPU memory
    name="yolo_segmentation",
    project="YOLO_Segmentation",
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 99.8MB/s]
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/YOLO_Segmentation/yolo_segmentation/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model(["/content/drive/MyDrive/Prof. Xiao Zhang TAI Lab/Tape Nail/YOLO2/dataset/test/images/image_001.jpg", "/content/drive/MyDrive/Prof. Xiao Zhang TAI Lab/Tape Nail/YOLO2/dataset/test/images/image_002.jpg"], stream=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 256x256 (no detections), 28.1ms
# 1: 256x256 (no detections), 28.1ms
# <PIL.Image.Image image mode=RGB size=640x640>
# <PIL.Image.Image image mode=RGB size=640x640>
# Speed: 1.2ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)

# %%
# !zip -r /content/yolo_segmentation2.zip /content/YOLO_Segmentation/yolo_segmentation

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !zip -r /content/yolo11_det_new.zip /content/YOLO_Segmentation/yolo_segmentation
# Out:
#   adding: content/YOLO_Segmentation/yolo_segmentation/ (stored 0%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/val_batch0_pred.jpg (deflated 9%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/R_curve.png (deflated 18%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/train_batch0.jpg (deflated 2%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/results.csv (deflated 64%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/results.png (deflated 7%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/events.out.tfevents.1742666864.31dcd683fd02.181.0 (deflated 89%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/train_batch2.jpg (deflated 2%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/train_batch542.jpg (deflated 7%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/confusion_matrix_normalized.png (deflated 33%)
#   adding: content/YOLO_Segmentation/yolo_segmentation/val_batch0_labels.jpg (deflated 10%)
# ...

# %%
# !mv /content/yolo_segmentation_new.zip /content/drive/MyDrive/Prof. Xiao Zhang TAI Lab/Tape Nail/YOLO2/content/yolo_segmentation_new.zip
# Out:
# mv: target 'Nail/YOLO2/content/yolo_segmentation_new.zip' is not a directory
